# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("magic_gamma_telescope04.csv")
df.head()
# Out:
#     flength    fwidth   fsize   fconc  fconc1      fsym  fm3long  fm3trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     falpha      dist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %%
dff = df.copy()

# %%
# get basic unsder standing of data
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19020 entries, 0 to 19019
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   flength   19020 non-null  float64
#  1   fwidth    19020 non-null  float64
#  2   fsize     19020 non-null  float64
#  3   fconc     19020 non-null  float64
#  4   fconc1    19020 non-null  float64
#  5   fsym      19020 non-null  float64
#  6   fm3long   19020 non-null  float64
#  7   fm3trans  19020 non-null  float64
#  8   falpha    19020 non-null  float64
#  9   dist      19020 non-null  float64
#  10  class     19020 non-null  object
# dtypes: float64(10), object(1)
# memory usage: 1.6+ MB

# %%
dff.shape
# Out:
# (19020, 11)

# %%
dff.columns
# Out:
# Index(['flength', 'fwidth', 'fsize', 'fconc', 'fconc1', 'fsym', 'fm3long',
#        'fm3trans', 'falpha', 'dist', 'class'],
#       dtype='object')

# %%
sns.pairplot(data = dff)

# %%
dff.describe()
# Out:
#             flength        fwidth         fsize         fconc        fconc1  \
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean      53.250154     22.180966      2.825017      0.380327      0.214657
# std       42.364855     18.346056      0.472599      0.182813      0.110511
# min        4.283500      0.000000      1.941300      0.013100      0.000300
# 25%       24.336000     11.863800      2.477100      0.235800      0.128475
# 50%       37.147700     17.139900      2.739600      0.354150      0.196500
# 75%       70.122175     24.739475      3.101600      0.503700      0.285225
# max      334.177000    256.382000      5.323300      0.893000      0.675200
#
#                fsym       fm3long      fm3trans        falpha          dist
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean      -4.331745     10.545545      0.249726     27.645707    193.818026
# std       59.206062     51.000118     20.827439     26.103621     74.731787
# min     -457.916100   -331.780000   -205.894700      0.000000      1.282600
# 25%      -20.586550    -12.842775    -10.849375      5.547925    142.492250
# 50%        4.013050     15.314100      0.666200     17.679500    191.851450
# 75%       24.063700     35.837800     10.946425     45.883550    240.563825
# max      575.240700    238.321000    179.851000     90.000000    495.561000

# %%
dff['class'].unique()
# Out:
# array(['g', 'h'], dtype=object)

# %%
dff['class'].replace({'g':1, 'h':0}, inplace =True)

# %%
dff['class'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
dff['class'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(data=dff,x='class',y='flength')
# Out:
# <AxesSubplot:xlabel='class', ylabel='flength'>

# %%
sns.boxplot(data=dff,x='class',y='flength')
# Out:
# <AxesSubplot:xlabel='class', ylabel='flength'>

# %%
sns.boxplot(data=dff,x='class',y='fwidth')
# Out:
# <AxesSubplot:xlabel='class', ylabel='fwidth'>

# %%
sns.boxplot(data=dff,x='class',y='fsize')
# Out:
# <AxesSubplot:xlabel='class', ylabel='fsize'>

# %%
sns.heatmap(dff.corr(),linewidths=0.5,annot=True, cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
X = dff.drop('class', axis =1)
y=dff['class']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# feature engineering
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train, X_test = scaler.fit_transform(X_train), scaler.transform(X_test)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from scikeras.wrappers import KerasClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-34-21b1e8d36f57> in <module>
# ----> 1 import tensorflow as tf
#       2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Dense, Dropout
#       4 from tensorflow.keras.callbacks import EarlyStopping
#       5 from tensorflow.keras.optimizers import Adam
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
model = Sequential()

model.add(Dense(16, input_shape=(10,), activation='relu'))
model.add(Dense(16, activation='relu'))

model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-70321bfd92e2> in <module>
# ----> 1 early_stop = EarlyStopping(monitor='val_loss', mode='min', patience=5)
#
# NameError: name 'EarlyStopping' is not defined

# %%
model.fit(X_train, y_train, batch_size=12, epochs=100, 
          validation_data=(X_test, y_test), callbacks=[early_stop])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-1ae144050c0e> in <module>
# ----> 1 model.fit(X_train, y_train, batch_size=12, epochs=100,
#       2           validation_data=(X_test, y_test), callbacks=[early_stop])
#
# NameError: name 'model' is not defined

# %%
nn_metrics = pd.DataFrame(model.history.history)
nn_metrics
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-91a497e72b3b> in <module>
# ----> 1 nn_metrics = pd.DataFrame(model.history.history)
#       2 nn_metrics
#
# NameError: name 'model' is not defined

# %%
#Evaluating Loss
nn_metrics[['loss', 'val_loss']].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-58881696d40d> in <module>
#       1 #Evaluating Loss
# ----> 2 nn_metrics[['loss', 'val_loss']].plot()
#
# NameError: name 'nn_metrics' is not defined

# %%
# Evaluating Accuracy
nn_metrics[['accuracy', 'val_accuracy']].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-e473bd846108> in <module>
#       1 # Evaluating Accuracy
# ----> 2 nn_metrics[['accuracy', 'val_accuracy']].plot()
#
# NameError: name 'nn_metrics' is not defined

# %%
predictions = (model.predict(X_test) > 0.5).astype('int32')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-b8bf65c5498e> in <module>
# ----> 1 predictions = (model.predict(X_test) > 0.5).astype('int32')
#
# NameError: name 'model' is not defined

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score
print(classification_report(y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-54441071eca7> in <module>
#       1 from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score
# ----> 2 print(classification_report(y_test, predictions))
#
# NameError: name 'predictions' is not defined

# %%
accuracy_score(y_test, predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-82664e54b52c> in <module>
# ----> 1 accuracy_score(y_test, predictions)
#
# NameError: name 'predictions' is not defined

# %%
f1_score(y_test, predictions)

# %%
def create_model(neurons, dropout_rate, optimizer='adam'):

	model = Sequential()
	model.add(Dense(neurons, input_shape=(10,), activation='relu'))
	model.add(Dropout(dropout_rate))
	model.add(Dense(1, activation='sigmoid'))
 
	model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
	return model

# %%
optimizer = ['SGD', 'RMSprop', 'Adam']
dropout_rate = [0.2, 0.3, 0.4, 0.5]
neurons = [15, 20, 25, 30]

param_grid = dict(model__optimizer=optimizer, model__dropout_rate=dropout_rate, 
                  model__neurons=neurons)

# %%
model = KerasClassifier(model=create_model, epochs=100, batch_size=10, verbose=0)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X, y)

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
